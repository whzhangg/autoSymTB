# %%
from automaticTB.interface import OrbitalPropertyRelationship

relationship = OrbitalPropertyRelationship.from_file("Si_2nn_relationship.dat")
relationship.print_free_pairs()

# %%
import numpy as np
'''
values = np.array([
    -4.81341,     # 1  > Pair: Si-00      3s -> Si-00      3s r = (  0.00,  0.00,  0.00)
    0.00579/4,    # 2  > Pair: Si-00     3px -> Si-00      4s r = (  2.72,  2.72,  0.00)
    0.00000,      # 3  > Pair: Si-00      4s -> Si-00      4s r = (  0.00, -2.72,  2.72)
    1.77563,      # 4  > Pair: Si-00     3px -> Si-00     3px r = (  0.00,  0.00,  0.00)
    5.61342,      # 5  > Pair: Si-00      4s -> Si-00      4s r = (  0.00,  0.00,  0.00)
    -8.33255/4,   # 6  > Pair: Si-00      3s -> Si-01      3s r = (  1.36, -1.36,  1.36)
    0.08002/4,    # 7  > Pair: Si-00      3s -> Si-00     3px r = (  2.72,  2.72,  0.00)
    5.86140/4,    # 8  > Pair: Si-00      3s -> Si-01     3px r = (  1.36, -1.36,  1.36)
    0.00000,      # 9  > Pair: Si-00      3s -> Si-01      4s r = (  1.36, -1.36,  1.36)
    0.00000,      #10  > Pair: Si-00      3s -> Si-00      4s r = (  2.72,  2.72,  0.00)
    -5.86140/4,   #11  > Pair: Si-00     3px -> Si-01      3s r = (  1.36, -1.36,  1.36)
    5.29091/4,    #12  > Pair: Si-00     3px -> Si-01     3pz r = (  1.36, -1.36,  1.36)
    1.69916/4,    #13  > Pair: Si-00     3px -> Si-01     3px r = (  1.36, -1.36,  1.36)
    0.55067/4,    #14  > Pair: Si-00     3pz -> Si-00     3px r = (  2.72,  0.00,  2.72)
    0.00762/4,    #15  > Pair: Si-00     3px -> Si-00     3px r = ( -2.72,  2.72,  0.00)
    -4.88308/4,   #16  > Pair: Si-00     3px -> Si-01      4s r = (  1.36, -1.36,  1.36)
    -0.10662/4,   #17  > Pair: Si-00     3px -> Si-00     3px r = (  0.00, -2.72,  2.72)
    0.00000,      #18  > Pair: Si-00      4s -> Si-01      3s r = (  1.36, -1.36,  1.36)
    4.88308/4,    #19  > Pair: Si-00      4s -> Si-01     3px r = (  1.36, -1.36,  1.36)
    0.00000,      #20  > Pair: Si-00      4s -> Si-01      4s r = (  1.36, -1.36,  1.36)
    0.01591/4,    #21  > Pair: Si-00      3s -> Si-00      3s r = (  0.00, -2.72,  2.72)
])
'''

values = np.array([ 
    -4.81341,
    #  1 > Pair: Si-01      3s -> Si-01      3s r = (  0.00,  0.00,  0.00)
    1.77563,
    #  2 > Pair: Si-01     3px -> Si-01     3px r = (  0.00,  0.00,  0.00)
    5.61342,
    #  3 > Pair: Si-01      4s -> Si-01      4s r = (  0.00,  0.00,  0.00)
    -8.33255/4,
    #  4 > Pair: Si-01      3s -> Si-00      3s r = (  1.36, -1.36, -1.36)
    -5.86140/4,
    #  5 > Pair: Si-01      3s -> Si-00     3px r = (  1.36, -1.36, -1.36)
    0.00000,
    #  6 > Pair: Si-01      3s -> Si-00      4s r = (  1.36, -1.36, -1.36)
    5.86140/4,
    #  7 > Pair: Si-01     3px -> Si-00      3s r = (  1.36, -1.36, -1.36)
    -5.29091/4,
    #  8 > Pair: Si-01     3px -> Si-00     3pz r = (  1.36, -1.36, -1.36)
    1.69916/4,
    #  9 > Pair: Si-01     3px -> Si-00     3px r = (  1.36, -1.36, -1.36)
    -4.88308/4,
    # 10 > Pair: Si-01     3px -> Si-00      4s r = (  1.36, -1.36, -1.36)
    0.00000,
    # 11 > Pair: Si-01      4s -> Si-00      3s r = (  1.36, -1.36, -1.36)
    4.88308/4,
    # 12 > Pair: Si-01      4s -> Si-00     3px r = (  1.36, -1.36, -1.36)
    0.00000,
    # 13 > Pair: Si-01      4s -> Si-00      4s r = (  1.36, -1.36, -1.36)
    0.01591/4,
    # 14 > Pair: Si-01      3s -> Si-01      3s r = (  2.72,  2.72,  0.00)
    -0.08002/4,
    # 15 > Pair: Si-01     3px -> Si-01      3s r = (  2.72,  2.72,  0.00)
    -0.10662/4,
    # 16 > Pair: Si-01     3px -> Si-01     3px r = (  0.00,  2.72,  2.72)
    0.55067/4,
    # 17 > Pair: Si-01     3px -> Si-01     3py r = (  2.72,  2.72,  0.00)
    0.00762/4,
    # 18 > Pair: Si-01     3px -> Si-01     3px r = (  2.72,  2.72,  0.00)
    0.00000,
    # 19 > Pair: Si-01      4s -> Si-01      3s r = (  2.72,  2.72,  0.00)
    -0.00579/4,
    # 20 > Pair: Si-01      4s -> Si-01     3px r = (  2.72,  2.72,  0.00)
    0.00000,
    # 21 > Pair: Si-01      4s -> Si-01      4s r = (  2.72,  2.72,  0.00)
])

model = relationship.get_ElectronicModel_from_free_parameters(free_Hijs=values)


path_str = ["L   0.5   0.5  0.5  G  0.0   0.0  0.0",
        "G   0.0   0.0  0.0  X  0.5   0.0  0.5",
        "X   0.5   0.0  0.5  U  0.625 0.25 0.625",
        "K 0.375 0.375 0.75  G  0.0   0.0  0.0"]

model.plot_bandstructure("Si_2nn", path_str)
